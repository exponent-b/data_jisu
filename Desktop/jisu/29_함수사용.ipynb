# %%
# 함수 만들기

def hello():
    print("hello")

hello()
hello()
# Out:
# hello
# hello

# %%
hello2()
hello2()

def hello2():
    print("hello")

# 파이썬은 함수 먼저 호출할 수 없다
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 hello2()
#       2 hello2()
#       3
#       4 def hello2():
#
# NameError: name 'hello2' is not defined

# %%
# 덧셈함수 만들기
def add(a, b):
    '''
    독스트링~~~~~~~~~
    설명 적는다~
    '''
    print(a + b)

add(10, 20)
# Out:
# 30

# %%
add.__doc__
# Out:
# '\n독스트링~~~~~~~~~\n설명 적는다~\n'
