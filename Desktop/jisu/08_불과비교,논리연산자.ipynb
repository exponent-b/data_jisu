# %%
# 불과 비교연산자 사용하기
print(True)
print(False)
# Out:
# True
# False

# %%
# 비교연산자
3 > 1
# Out:
# True

# %%
print(10 == 10)
print(10 != 3)
# Out:
# True
# True

# %%
print("python" == "python")

# %%
# 부등호 사용하기
print(10 > 20)
print(10 < 20)
print(10 >= 20)
print(10 <= 20)
# Out:
# False
# True
# False
# True

# %%
# 객체가 같은지 다른지 비교하기
print(1 == 1, 0)
print(1 is 1.0)
print(1 is not 1.0)
# Out:
# True 0
# False
# True
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\KDS-18\AppData\Local\Temp\ipykernel_3276\556086002.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(1 is 1.0)
# C:\Users\KDS-18\AppData\Local\Temp\ipykernel_3276\556086002.py:4: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   print(1 is not 1.0)

# %%
# 논리 연산자 사용하기
print(True and False)
print(False and True)
print(True and True)
print(False and False)
# Out:
# False
# False
# True
# False

# %%
print(True or False)
print(False or True)
print(True or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
print(not True)
print(not False)
# Out:
# False
# True

# %%
not True and False or not False
# true?
# Out:
# True

# %%
# 논리연산자와 비교연산자를 함께 사용하기
10 == 10 and 10 != 5
# Out:
# True

# %%
print(10 > 5 or 10 < 3)
print(not 10 > 5)
print(not 1 is 1.0)
# Out:
# True
# False
# True
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\KDS-18\AppData\Local\Temp\ipykernel_3276\1842497900.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0)

# %%
8 is 8.0 # false
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\KDS-18\AppData\Local\Temp\ipykernel_3276\938522566.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   8 is 8.0 # false
# False

# %%
korean = 92
english = 47
math = 86
sci = 81

print(korean >= 50 and english >= 50 and math >= 50 and sci >= 50)
# Out:
# False

# %%
kor, eng, math, sci = map(int, input().split())
print(kor >= 90 and eng > 80 and math > 85 and sci >= 80)
# Out:
# False
