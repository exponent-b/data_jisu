# %%
# if조건문 사용하기
x = 10
if x == 10:
    print("10")
# Out:
# 10

# %%
# if조건문에서 코드 생략하기
x = 10
if x == 10:
    pass

# %%
# if 들여쓰기
x = 10
if x == 10:
    print("x에 들어가는 숫자는")
        print("10")
# Out:
#   Cell In[2], line 5
#     print("10")
#     ^
# IndentationError: unexpected indent

# %%
x = 10
if x == 10:
    print("x에 들어가는 숫자는", end = '----')
print("10")
# Out:
# x에 들어가는 숫자는----10

# %%
# 중첩 if의 조건문
x = 15
if x >= 10:
    print("10이상입니다")

    if x == 15:
        print("15")

        if x == 20:
            print("20")
# Out:
# 10이상입니다
# 15

# %%
x = int(input())

if x == 10:
    print("10")

if x == 20:
    print("20")
# Out:
# 10

# %%
pay = int(input("금액"))
cu = (input("쿠폰"))
if cu == 'cash3000':
    pay -= 3000
elif cu == 'cash5000':
    pay -= 5000

print(pay)
# Out:
# 24000
