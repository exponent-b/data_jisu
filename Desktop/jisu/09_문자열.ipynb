# %%
hello = "hello world"
print(hello)
# Out:
# hello world

# %%
hello = "안녕"
print(hello)
# Out:
# 안녕

# %%
hello = """oooooooooooo"""
print(hello)
# Out:
# oooooooooooo

# %%
# 여러줄로 된 문자열 사용하기
# ''' 또는 """만 가능
hello = """ooooooooooo
안녕하세오
py입니다

---




"""
print(hello)
# Out:
# ooooooooooo
# 안녕하세오
# py입니다
#
# ---

# %%
# 문자열 안에 작은 따옴표나 큰 따옴표 사용하기
a = "python is'sssssssssss"
print(a)
# Out:
# python is'sssssssssss

# %%
s = """'python' is a "programming language"
that lets you work quickly
and
integrate system more effectively."""
print(s)
# Out:
# 'python' is a "programming language"
# that lets you work quickly
# and
# integrate system more effectively.
