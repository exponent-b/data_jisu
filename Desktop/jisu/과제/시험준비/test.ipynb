# %%
#18단원// 연습 p.211

# %%
# 7단원// p.80 출력방법 알아보기
## 연습문제
year =2000
month = 10
day = 27
hour = 11
min = 43
sec = 59

print(year, month, day, sep = "/", end = " ")
print(hour, min, sec, sep = ":")
# Out:
# 2000/10/27 11:43:59

# %%
## 심사
year =2000
month = 10
day = 27
hour = 11
min = 43
sec = 59

print(year, month, day, sep = "-", end = "T")
print(hour, min, sec, sep = ":")
# Out:
# 2000-10-27T11:43:59

# %%
# 10 리스트와 튜플// p.109
## 연습
a = list(range(5, -10, -2))
print(a)
# Out:
# [5, 3, 1, -1, -3, -5, -7, -9]

# %%
## 심사
n1,n2 = -10, 10
step = int(input())
result = tuple(range(n1, n2 + 1, step))

print(result)
# Out:
# (-10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10)

# %%
# 11 p.142
## 심사
a = "python"
b = "python"

a_1 = a[1::2]
b_2 = b[::2]

print(a_1 + b_2)
# Out:
# yhnpto

# %%
# 17 p.202
## 연습
i = 2
j = 5

while i <= 32 and j >= 1:
    print(i, j)
    i *= 2
    j -= 1
# Out:
# 2 5
# 4 4
# 8 3
# 16 2
# 32 1

# %%
## 심사
money = 10000
fee = 1350

while money >= 1350:
    money -= 1350
    print(money)
# Out:
# 8650
# 7300
# 5950
# 4600
# 3250
# 1900
# 550

# %%
# 18 p.211 @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
## 연습
i = 0
while True:
    if i % 10 != 3:
        i += 1
        continue
    if  i > 73:
        i += 1
        break
        
    print(i, end = ' ')
    i += 1
# Out:
# 3 13 23 33 43 53 63 73

# %%
# Out:
# 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 20 3 13 2
# ...
